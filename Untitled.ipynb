# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
root_dir="teamfiles"
all_data_df= pd.DataFrame()
all_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
years=['1516', '1617','1718', '1819']

for year in years:
    year_df = pd.read_csv(f"{root_dir}/season-{year}_csv.csv")
    year_df['Season'] = year
        
    all_data_df = all_data_df.append(year_df)
   
    #all_data_df.merge(soccer_data1)
    print(f"{root_dir}/season-{year}_csv")

all_data_df
# Out:
# teamfiles/season-1516_csv
# teamfiles/season-1617_csv
# teamfiles/season-1718_csv
# teamfiles/season-1819_csv
#     Div        Date     HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0    08/08/15  Bournemouth   Aston Villa     0     1   A     0     0
# 1    E0    08/08/15      Chelsea       Swansea     2     2   D     2     1
# 2    E0    08/08/15      Everton       Watford     2     2   D     0     1
# 3    E0    08/08/15    Leicester    Sunderland     4     2   H     3     0
# 4    E0    08/08/15   Man United     Tottenham     1     0   H     1     0
# ..   ..         ...          ...           ...   ...   ...  ..   ...   ...
# 375  E0  12/05/2019    Liverpool        Wolves     2     0   H     1     0
# 376  E0  12/05/2019   Man United       Cardiff     0     2   A     0     1
# 377  E0  12/05/2019  Southampton  Huddersfield     1     1   D     1     0
# 378  E0  12/05/2019    Tottenham       Everton     2     2   D     1     0
# 379  E0  12/05/2019      Watford      West Ham     1     4   A     0     2
#
#     HTR  ... BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  PSCD  \
# 0     D  ...   26   -0.5     1.98     1.93     1.99     1.92  1.82  3.88
# 1     H  ...   27   -1.5     2.24     2.16     1.80     1.73  1.37  5.04
# 2     A  ...   26   -1.0     2.28     2.18     1.76     1.71  1.75  3.76
# 3     H  ...   26   -0.5     2.00     1.95     1.96     1.90  1.79  3.74
# 4     H  ...   26   -1.0     2.20     2.09     1.82     1.78  1.64  4.07
# ..   ..  ...  ...    ...      ...      ...      ...      ...   ...   ...
# 375   H  ...   22   -1.5     1.98     1.91     2.01     1.95  1.32  5.89
# 376   A  ...   21   -2.0     2.52     2.32     1.72     1.64  1.30  6.06
# 377   H  ...   22   -1.5     2.27     2.16     1.80     1.73  1.37  5.36
# 378   H  ...   19   -0.5     2.13     2.08     1.85     1.80  1.91  3.81
# 379   A  ...   19   -0.5     2.25     2.19     1.78     1.72  2.11  3.86
#
#       PSCA  Season
# 0     4.70    1516
# 1    10.88    1516
# 2     5.44    1516
# 3     5.10    1516
# 4     6.04    1516
# ..     ...     ...
# 375   9.48    1819
# 376   9.71    1819
# 377   8.49    1819
# 378   4.15    1819
# 379   3.41    1819
#
# [1520 rows x 66 columns]

# %%
xcolumns = ['Div','B365H', 'B365D', 'B365A', 'BWH', 'BWD',
       'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'PSH', 'PSD', 'PSA',
       'WHH', 'WHD', 'WHA', 'VCH', 'VCD', 'VCA', 'Bb1X2', 'BbMxH', 'BbAvH',
       'BbMxD', 'BbAvD', 'BbMxA', 'BbAvA', 'BbOU', 'BbMx>2.5', 'BbAv>2.5',
       'BbMx<2.5', 'BbAv<2.5', 'BbAH', 'BbAHh', 'BbMxAHH', 'BbAvAHH',
       'BbMxAHA', 'BbAvAHA', 'PSCH', 'PSCD', 'PSCA', 'Referee']
all_data_df.drop(labels=xcolumns, axis=1, inplace=True)

# %%
all_data_df.columns
# Out:
# Index(['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG',
#        'HTR', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY',
#        'HR', 'AR', 'Season'],
#       dtype='object')

# %%
all_data_df.rename(columns={'FTHG': 'FT Home Goals', 'FTAG': 'FT Away Goals', 'FTR':'FT Winner', 'HTHG': 'HT Home Goals',
                           'HTAG': 'HT Away Goals', 'HTR': 'HT Winner', 'HS': 'Home Shots', 'AS': 'Away Shots',
                           'HST': 'Home Shots OT', 'AST': 'Away Shots OT', 'HF': 'Home Fouls', 'AF': 'Away Fouls', 
                           'HC': 'Home Corners', 'AC': 'Away Corner', 'HY': 'Home Yellow Cards', 'AY': 'Away Yellow Cards',
                           'HR': 'Home Red Cards', 'AR': 'Away Red Cards'},inplace=True)
all_data_df
# Out:
#            Date     HomeTeam      AwayTeam  FT Home Goals  FT Away Goals  \
# 0      08/08/15  Bournemouth   Aston Villa              0              1
# 1      08/08/15      Chelsea       Swansea              2              2
# 2      08/08/15      Everton       Watford              2              2
# 3      08/08/15    Leicester    Sunderland              4              2
# 4      08/08/15   Man United     Tottenham              1              0
# ..          ...          ...           ...            ...            ...
# 375  12/05/2019    Liverpool        Wolves              2              0
# 376  12/05/2019   Man United       Cardiff              0              2
# 377  12/05/2019  Southampton  Huddersfield              1              1
# 378  12/05/2019    Tottenham       Everton              2              2
# 379  12/05/2019      Watford      West Ham              1              4
#
#     FT Winner  HT Home Goals  HT Away Goals HT Winner  Home Shots  ...  \
# 0           A              0              0         D          11  ...
# 1           D              2              1         H          11  ...
# 2           D              0              1         A          10  ...
# 3           H              3              0         H          19  ...
# 4           H              1              0         H           9  ...
# ..        ...            ...            ...       ...         ...  ...
# 375         H              1              0         H          13  ...
# 376         A              0              1         A          26  ...
# 377         D              1              0         H          10  ...
# 378         D              1              0         H          11  ...
# 379         A              0              2         A          17  ...
#
#      Away Shots OT  Home Fouls  Away Fouls  Home Corners  Away Corner  \
# 0                3          13          13             6            3
# 1               10          15          16             4            8
# 2                5           7          13             8            2
# 3                5          13          17             6            3
# 4                4          12          12             1            2
# ..             ...         ...         ...           ...          ...
# 375              2           3          11             4            1
# 376              4           9           6            11            2
# 377              3           8           6             4            3
# 378              9          10          13             7            4
# 379              9          10          10             7            2
#
#      Home Yellow Cards  Away Yellow Cards  Home Red Cards  Away Red Cards  \
# 0                    3                  4               0               0
# 1                    1                  3               1               0
# 2                    1                  2               0               0
# 3                    2                  4               0               0
# 4                    2                  3               0               0
# ..                 ...                ...             ...             ...
# 375                  0                  2               0               0
# 376                  3                  3               0               0
# 377                  0                  1               0               0
# 378                  0                  2               0               0
# 379                  1                  0               1               0
#
#      Season
# 0      1516
# 1      1516
# 2      1516
# 3      1516
# 4      1516
# ..      ...
# 375    1819
# 376    1819
# 377    1819
# 378    1819
# 379    1819
#
# [1520 rows x 22 columns]

# %%
for idx, row in all_data_df.iterrows():
    if row['FT Winner'] == 'H':
        all_data_df.loc[idx, 'Home Points'] = 3
        all_data_df.loc[idx, 'Away Points'] = 0
        all_data_df.loc[idx, 'Home Win'] = 1
        all_data_df.loc[idx, 'Away Win'] = 0
        all_data_df.loc[idx, 'Draw'] = 0
    elif row['FT Winner'] == 'A':
        all_data_df.loc[idx, 'Home Points'] = 0
        all_data_df.loc[idx, 'Away Points'] = 3
        all_data_df.loc[idx, 'Home Win'] = 0
        all_data_df.loc[idx, 'Away Win'] = 1
        all_data_df.loc[idx, 'Draw'] = 0
    elif row['FT Winner'] == 'D':
        all_data_df.loc[idx, 'Home Points'] = 1
        all_data_df.loc[idx, 'Away Points'] = 1
        all_data_df.loc[idx, 'Home Win'] = 0
        all_data_df.loc[idx, 'Away Win'] = 0
        all_data_df.loc[idx, 'Draw'] = 1
all_data_df
# Out:
#            Date     HomeTeam      AwayTeam  FT Home Goals  FT Away Goals  \
# 0      08/08/15  Bournemouth   Aston Villa              0              1
# 1      08/08/15      Chelsea       Swansea              2              2
# 2      08/08/15      Everton       Watford              2              2
# 3      08/08/15    Leicester    Sunderland              4              2
# 4      08/08/15   Man United     Tottenham              1              0
# ..          ...          ...           ...            ...            ...
# 375  12/05/2019    Liverpool        Wolves              2              0
# 376  12/05/2019   Man United       Cardiff              0              2
# 377  12/05/2019  Southampton  Huddersfield              1              1
# 378  12/05/2019    Tottenham       Everton              2              2
# 379  12/05/2019      Watford      West Ham              1              4
#
#     FT Winner  HT Home Goals  HT Away Goals HT Winner  Home Shots  ...  \
# 0           A              0              0         D          11  ...
# 1           D              2              1         H          11  ...
# 2           D              0              1         A          10  ...
# 3           H              3              0         H          19  ...
# 4           H              1              0         H           9  ...
# ..        ...            ...            ...       ...         ...  ...
# 375         H              1              0         H          13  ...
# 376         A              0              1         A          26  ...
# 377         D              1              0         H          10  ...
# 378         D              1              0         H          11  ...
# 379         A              0              2         A          17  ...
#
#      Home Yellow Cards  Away Yellow Cards  Home Red Cards  Away Red Cards  \
# 0                    3                  4               0               0
# 1                    1                  3               1               0
# 2                    1                  2               0               0
# 3                    2                  4               0               0
# 4                    2                  3               0               0
# ..                 ...                ...             ...             ...
# 375                  0                  2               0               0
# 376                  3                  3               0               0
# 377                  0                  1               0               0
# 378                  0                  2               0               0
# 379                  1                  0               1               0
#
#      Season  Home Points  Away Points  Home Win  Away Win  Draw
# 0      1516          3.0          0.0       1.0       0.0   0.0
# 1      1516          3.0          0.0       1.0       0.0   0.0
# 2      1516          0.0          3.0       0.0       1.0   0.0
# 3      1516          0.0          3.0       0.0       1.0   0.0
# 4      1516          0.0          3.0       0.0       1.0   0.0
# ..      ...          ...          ...       ...       ...   ...
# 375    1819          3.0          0.0       1.0       0.0   0.0
# 376    1819          0.0          3.0       0.0       1.0   0.0
# 377    1819          1.0          1.0       0.0       0.0   1.0
# 378    1819          1.0          1.0       0.0       0.0   1.0
# 379    1819          0.0          3.0       0.0       1.0   0.0
#
# [1520 rows x 27 columns]

# %%
all_data_df.loc[all_data_df['FT Winner']=='H', 'Home Points']  = 3 
all_data_df.loc[all_data_df['FT Winner']=='H', 'Home Win']  = 1
all_data_df.loc[all_data_df['FT Winner']=='H', 'Away Win']  = 0 
all_data_df.loc[all_data_df['FT Winner']=='H', 'Draw']  = 0 
all_data_df.loc[all_data_df['FT Winner']=='H', 'Away Points']  = 0
all_data_df.loc[all_data_df['FT Winner']=='A', 'Away Points']  = 3
all_data_df.loc[all_data_df['FT Winner']=='A', 'Away Win']  = 1 
all_data_df.loc[all_data_df['FT Winner']=='A', 'Home Win']  = 0 
all_data_df.loc[all_data_df['FT Winner']=='A', 'Draw']  = 0 
all_data_df.loc[all_data_df['FT Winner']=='A', 'Home Points']  = 0
all_data_df.loc[all_data_df['FT Winner']=='D', 'Home Points']  = 1
all_data_df.loc[all_data_df['FT Winner']=='D', 'Away Points']  = 1
all_data_df.loc[all_data_df['FT Winner']=='D', 'Draw']  = 1 
all_data_df.loc[all_data_df['FT Winner']=='D', 'Home Win']  = 0 
all_data_df.loc[all_data_df['FT Winner']=='D', 'Away Win']  = 0 
all_data_df
# Out:
#            Date     HomeTeam      AwayTeam  FT Home Goals  FT Away Goals  \
# 0      08/08/15  Bournemouth   Aston Villa              0              1
# 1      08/08/15      Chelsea       Swansea              2              2
# 2      08/08/15      Everton       Watford              2              2
# 3      08/08/15    Leicester    Sunderland              4              2
# 4      08/08/15   Man United     Tottenham              1              0
# ..          ...          ...           ...            ...            ...
# 375  12/05/2019    Liverpool        Wolves              2              0
# 376  12/05/2019   Man United       Cardiff              0              2
# 377  12/05/2019  Southampton  Huddersfield              1              1
# 378  12/05/2019    Tottenham       Everton              2              2
# 379  12/05/2019      Watford      West Ham              1              4
#
#     FT Winner  HT Home Goals  HT Away Goals HT Winner  Home Shots  ...  \
# 0           A              0              0         D          11  ...
# 1           D              2              1         H          11  ...
# 2           D              0              1         A          10  ...
# 3           H              3              0         H          19  ...
# 4           H              1              0         H           9  ...
# ..        ...            ...            ...       ...         ...  ...
# 375         H              1              0         H          13  ...
# 376         A              0              1         A          26  ...
# 377         D              1              0         H          10  ...
# 378         D              1              0         H          11  ...
# 379         A              0              2         A          17  ...
#
#      Home Yellow Cards  Away Yellow Cards  Home Red Cards  Away Red Cards  \
# 0                    3                  4               0               0
# 1                    1                  3               1               0
# 2                    1                  2               0               0
# 3                    2                  4               0               0
# 4                    2                  3               0               0
# ..                 ...                ...             ...             ...
# 375                  0                  2               0               0
# 376                  3                  3               0               0
# 377                  0                  1               0               0
# 378                  0                  2               0               0
# 379                  1                  0               1               0
#
#      Season  Home Points  Away Points  Home Win  Away Win  Draw
# 0      1516          0.0          3.0       0.0       1.0   0.0
# 1      1516          1.0          1.0       0.0       0.0   1.0
# 2      1516          1.0          1.0       0.0       0.0   1.0
# 3      1516          3.0          0.0       1.0       0.0   0.0
# 4      1516          3.0          0.0       1.0       0.0   0.0
# ..      ...          ...          ...       ...       ...   ...
# 375    1819          3.0          0.0       1.0       0.0   0.0
# 376    1819          0.0          3.0       0.0       1.0   0.0
# 377    1819          1.0          1.0       0.0       0.0   1.0
# 378    1819          1.0          1.0       0.0       0.0   1.0
# 379    1819          0.0          3.0       0.0       1.0   0.0
#
# [1520 rows x 27 columns]

# %%
#all_data_df['Date'].str.split('/')

# %%
teams = all_data_df['HomeTeam'].value_counts()
teams
# Out:
# Arsenal           76
# West Ham          76
# Liverpool         76
# Chelsea           76
# Crystal Palace    76
# Tottenham         76
# Man United        76
# Watford           76
# Southampton       76
# Man City          76
# Leicester         76
# Everton           76
# Bournemouth       76
# Burnley           57
# Newcastle         57
# Swansea           57
# West Brom         57
# Stoke             57
# Sunderland        38
# Huddersfield      38
# Brighton          38
# Cardiff           19
# Norwich           19
# Fulham            19
# Wolves            19
# Aston Villa       19
# Middlesbrough     19
# Hull              19
# Name: HomeTeam, dtype: int64

# %%
home_wins = all_data_df.groupby('HomeTeam')['Home Points' ,'Home Win', 'Draw'].sum()
away_wins = all_data_df.groupby('AwayTeam')['Away Points' ,'Away Win', 'Draw'].sum()
away_wins = away_wins.rename(columns={'Draw': 'Away Draws'})
wins= pd.concat([home_wins,away_wins], axis=1)

wins['Total Draws'] = wins['Draw'] + wins['Away Draws']
wins['Total Points'] = wins['Home Points'] + wins['Away Points'] 
wins.sort_values('Total Points',ascending=False)
# Out:
# C:\Users\ethom\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\ethom\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                 Home Points  Home Win  Draw  Away Points  Away Win  \
# Man City              182.0      57.0  11.0        160.0      49.0
# Liverpool             169.0      49.0  22.0        139.0      40.0
# Tottenham             170.0      52.0  14.0        134.0      39.0
# Chelsea               154.0      45.0  19.0        131.0      39.0
# Man United            158.0      45.0  23.0        124.0      36.0
# Arsenal               177.0      55.0  12.0        102.0      28.0
# Leicester             130.0      37.0  19.0         94.0      25.0
# Everton               134.0      39.0  17.0         77.0      17.0
# West Ham              117.0      32.0  21.0         84.0      21.0
# Southampton           102.0      26.0  24.0         82.0      20.0
# Bournemouth           106.0      29.0  19.0         71.0      18.0
# Watford               106.0      29.0  19.0         70.0      19.0
# Crystal Palace         87.0      24.0  15.0         89.0      24.0
# Burnley                82.0      24.0  10.0         52.0      12.0
# Stoke                  75.0      20.0  15.0         53.0      12.0
# Newcastle              81.0      23.0  12.0         45.0      10.0
# Swansea                78.0      22.0  12.0         43.0      10.0
# West Brom              70.0      18.0  16.0         49.0      10.0
# Brighton               52.0      13.0  13.0         24.0       5.0
# Sunderland             38.0       9.0  11.0         25.0       6.0
# Wolves                 34.0      10.0   4.0         23.0       6.0
# Huddersfield           32.0       8.0   8.0         21.0       4.0
# Norwich                23.0       6.0   5.0         11.0       3.0
# Hull                   28.0       8.0   4.0          6.0       1.0
# Cardiff                20.0       6.0   2.0         14.0       4.0
# Middlesbrough          18.0       4.0   6.0         10.0       1.0
# Fulham                 21.0       6.0   3.0          5.0       1.0
# Aston Villa            11.0       2.0   5.0          6.0       1.0
#
#                 Away Draws  Total Draws  Total Points
# Man City              13.0         24.0         342.0
# Liverpool             19.0         41.0         308.0
# Tottenham             17.0         31.0         304.0
# Chelsea               14.0         33.0         285.0
# Man United            16.0         39.0         282.0
# Arsenal               18.0         30.0         279.0
# Leicester             19.0         38.0         224.0
# Everton               26.0         43.0         211.0
# West Ham              21.0         42.0         201.0
# Southampton           22.0         46.0         184.0
# Bournemouth           17.0         36.0         177.0
# Watford               13.0         32.0         176.0
# Crystal Palace        17.0         32.0         176.0
# Burnley               16.0         26.0         134.0
# Stoke                 17.0         32.0         128.0
# Newcastle             15.0         27.0         126.0
# Swansea               13.0         25.0         121.0
# West Brom             19.0         35.0         119.0
# Brighton               9.0         22.0          76.0
# Sunderland             7.0         18.0          63.0
# Wolves                 5.0          9.0          57.0
# Huddersfield           9.0         17.0          53.0
# Norwich                2.0          7.0          34.0
# Hull                   3.0          7.0          34.0
# Cardiff                2.0          4.0          34.0
# Middlesbrough          7.0         13.0          28.0
# Fulham                 2.0          5.0          26.0
# Aston Villa            3.0          8.0          17.0

# %%
wins = wins.drop(['Draw', 'Away Draws'], axis=1)
wins
# Out:
#                 Home Points  Home Win  Away Points  Away Win  Total Draws  \
# Arsenal               177.0      55.0        102.0      28.0         30.0
# Aston Villa            11.0       2.0          6.0       1.0          8.0
# Bournemouth           106.0      29.0         71.0      18.0         36.0
# Brighton               52.0      13.0         24.0       5.0         22.0
# Burnley                82.0      24.0         52.0      12.0         26.0
# Cardiff                20.0       6.0         14.0       4.0          4.0
# Chelsea               154.0      45.0        131.0      39.0         33.0
# Crystal Palace         87.0      24.0         89.0      24.0         32.0
# Everton               134.0      39.0         77.0      17.0         43.0
# Fulham                 21.0       6.0          5.0       1.0          5.0
# Huddersfield           32.0       8.0         21.0       4.0         17.0
# Hull                   28.0       8.0          6.0       1.0          7.0
# Leicester             130.0      37.0         94.0      25.0         38.0
# Liverpool             169.0      49.0        139.0      40.0         41.0
# Man City              182.0      57.0        160.0      49.0         24.0
# Man United            158.0      45.0        124.0      36.0         39.0
# Middlesbrough          18.0       4.0         10.0       1.0         13.0
# Newcastle              81.0      23.0         45.0      10.0         27.0
# Norwich                23.0       6.0         11.0       3.0          7.0
# Southampton           102.0      26.0         82.0      20.0         46.0
# Stoke                  75.0      20.0         53.0      12.0         32.0
# Sunderland             38.0       9.0         25.0       6.0         18.0
# Swansea                78.0      22.0         43.0      10.0         25.0
# Tottenham             170.0      52.0        134.0      39.0         31.0
# Watford               106.0      29.0         70.0      19.0         32.0
# West Brom              70.0      18.0         49.0      10.0         35.0
# West Ham              117.0      32.0         84.0      21.0         42.0
# Wolves                 34.0      10.0         23.0       6.0          9.0
#
#                 Total Points
# Arsenal                279.0
# Aston Villa             17.0
# Bournemouth            177.0
# Brighton                76.0
# Burnley                134.0
# Cardiff                 34.0
# Chelsea                285.0
# Crystal Palace         176.0
# Everton                211.0
# Fulham                  26.0
# Huddersfield            53.0
# Hull                    34.0
# Leicester              224.0
# Liverpool              308.0
# Man City               342.0
# Man United             282.0
# Middlesbrough           28.0
# Newcastle              126.0
# Norwich                 34.0
# Southampton            184.0
# Stoke                  128.0
# Sunderland              63.0
# Swansea                121.0
# Tottenham              304.0
# Watford                176.0
# West Brom              119.0
# West Ham               201.0
# Wolves                  57.0

# %%
home_wins.plot(kind='bar', rot=45, figsize=(15,5))

# %%
away_wins.plot(kind='bar', rot=45, figsize=(15,5))

# %%
wins.plot(kind='bar', rot=45, figsize=(25,5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-24af3fab5645> in <module>
# ----> 1 wins.plot(kind='bar', rot=45, figsize=(25,5))
#
# AttributeError: 'NoneType' object has no attribute 'plot'
